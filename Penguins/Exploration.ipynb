# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("training_set_observations.csv")  #,index_col=[0, 1]

# %%
data.head()
# Out:
#    Unnamed: 0     site_name site_id ccamlr_region  longitude_epsg_4326  \
# 0           0  Acuna Island    ACUN          48.2              -44.637
# 1           1  Acuna Island    ACUN          48.2              -44.637
# 2           2  Acuna Island    ACUN          48.2              -44.637
# 3           3  Acuna Island    ACUN          48.2              -44.637
# 4           4  Acuna Island    ACUN          48.2              -44.637
#
#    latitude_epsg_4326        common_name   day  month  year  season_starting  \
# 0            -60.7612  chinstrap penguin  28.0   12.0  1983             1983
# 1            -60.7612     adelie penguin   NaN    NaN  1993             1993
# 2            -60.7612     adelie penguin   NaN    NaN  1994             1994
# 3            -60.7612     adelie penguin   NaN    NaN  2004             2004
# 4            -60.7612     adelie penguin  25.0    2.0  2011             2010
#
#    penguin_count  accuracy count_type vantage   e_n
# ...

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'site_name', u'site_id', u'ccamlr_region',
#        u'longitude_epsg_4326', u'latitude_epsg_4326', u'common_name', u'day',
#        u'month', u'year', u'season_starting', u'penguin_count', u'accuracy',
#        u'count_type', u'vantage', u'e_n'],
#       dtype='object')

# %%
data = data.drop('Unnamed: 0',axis=1)

# %%
data.head()
# Out:
#       site_name site_id ccamlr_region  longitude_epsg_4326  \
# 0  Acuna Island    ACUN          48.2              -44.637
# 1  Acuna Island    ACUN          48.2              -44.637
# 2  Acuna Island    ACUN          48.2              -44.637
# 3  Acuna Island    ACUN          48.2              -44.637
# 4  Acuna Island    ACUN          48.2              -44.637
#
#    latitude_epsg_4326        common_name   day  month  year  season_starting  \
# 0            -60.7612  chinstrap penguin  28.0   12.0  1983             1983
# 1            -60.7612     adelie penguin   NaN    NaN  1993             1993
# 2            -60.7612     adelie penguin   NaN    NaN  1994             1994
# 3            -60.7612     adelie penguin   NaN    NaN  2004             2004
# 4            -60.7612     adelie penguin  25.0    2.0  2011             2010
#
#    penguin_count  accuracy count_type vantage   e_n
# 0         4000.0       4.0      nests  ground  0.50
# ...

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# site_name                 0
# site_id                   0
# ccamlr_region             0
# longitude_epsg_4326       0
# latitude_epsg_4326        0
# common_name               0
# day                    1155
# month                   726
# year                      0
# season_starting           0
# penguin_count            17
# accuracy                 17
# count_type                0
# vantage                  98
# e_n                      17
# dtype: int64

# %%
data.shape
# Out:
# (2952, 15)

# %%
data.dtypes
# Out:
# site_name               object
# site_id                 object
# ccamlr_region           object
# longitude_epsg_4326    float64
# latitude_epsg_4326     float64
# common_name             object
# day                    float64
# month                  float64
# year                     int64
# season_starting          int64
# penguin_count          float64
# accuracy               float64
# count_type              object
# vantage                 object
# e_n                    float64
# dtype: object

# %%
(data[data.year != data.season_starting])
# Out:
#                                              site_name site_id ccamlr_region  \
# 4                                         Acuna Island    ACUN          48.2
# 6                                         Adams Island    ADAM        58.4.1
# 14                                          Cape Adare    ADAR          88.1
# 19                  Barrientos Island (Aitcho Islands)    AITC          48.1
# 21                  Barrientos Island (Aitcho Islands)    AITC          48.1
# 25                  Barrientos Island (Aitcho Islands)    AITC          48.1
# 29                  Barrientos Island (Aitcho Islands)    AITC          48.1
# 34                  Barrientos Island (Aitcho Islands)    AITC          48.1
# 38                                        Akarui Point    AKAR        58.4.2
# 39                                     Alasheyev Bight    ALAS        58.4.2
# 41                                       Alcock Island    ALCO          48.1
# ...

# %% [markdown]
# BENN	chinstrap penguin	NaN	NaN	NaN	NaN	NaN
# BENT	adelie penguin	NaN	NaN	NaN	NaN	NaN
# BERK	adelie penguin	NaN	13423.0	NaN	NaN	NaN
# BERN	gentoo penguin	NaN	NaN	NaN	NaN	NaN
# BERT	adelie penguin

# %%
data[(data.common_name=="chinstrap penguin")].shape
# Out:
# (774, 15)

# %%
data[(data.common_name=="adelie penguin")].shape
# Out:
# (1387, 15)

# %%
data[(data.common_name=="gentoo penguin")].shape
# Out:
# (791, 15)

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# site_name               619
# site_id                 619
# ccamlr_region             7
# longitude_epsg_4326     609
# latitude_epsg_4326      589
# common_name               3
# day                      32
# month                     7
# year                     54
# season_starting          58
# penguin_count          1909
# accuracy                  6
# count_type                3
# vantage                   8
# e_n                       6
# dtype: int64

# %%
pd.to_datetime(data[['year', 'month', 'day']])

# %%
df = pd.DataFrame({'year': [2015, 2016],
                       'month': [2, None],
                       'day': [4, 5]})

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1          NaT
# dtype: datetime64[ns]

# %%
print data.month.unique()
# Out:
# [ 12.  nan   2.  11.   1.   3.  10.]

# %%
data.month.value_counts()
# Out:
# 12.0    987
# 1.0     685
# 2.0     338
# 11.0    197
# 3.0      15
# 10.0      4
# Name: month, dtype: int64

# %%
data.month.value_counts().index[0]
# Out:
# 12.0

# %%
data.month.fillna(data.month.value_counts().index[0],inplace=True)

# %%
data.day.fillna(data.day.value_counts().index[0],inplace=True)

# %%
data.to_csv("training_modified.csv",index=False)

# %%
data.year.value_counts().sort_index()

# %%
pd.to_datetime(data[['year', 'month','day']],errors='coerce')

# %%
penguins = ["chinstrap penguin","adelie penguin","gentoo penguin"]
